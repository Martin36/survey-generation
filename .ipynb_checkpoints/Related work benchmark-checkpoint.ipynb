# %%
import seaborn as sns
import pandas as pd

from utils_package.util_funcs import load_json

STATS_PATH = "stats/rel_work_benchmark_stats.json"

stats = load_json(STATS_PATH)

penguins = sns.load_dataset("penguins")
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
stats
# Out:
# {'aburaed_et_at input distribution': {'16': 1,
#   '20': 1,
#   '22': 1,
#   '23': 3,
#   '24': 2,
#   '25': 1,
#   '26': 10,
#   '27': 9,
#   '28': 19,
#   '29': 14,
#   '30': 12,
#   '31': 19,
#   '32': 22,
#   '33': 24,
#   '34': 25,
#   '35': 32,
#   '36': 35,
#   '37': 50,
#   '38': 41,
#   '39': 54,
#   '40': 42,
#   '41': 55,
#   '42': 62,
#   '43': 51,
#   '44': 65,
#   '45': 67,
#   '46': 68,
#   '47': 81,
#   '48': 73,
#   '49': 73,
#   '50': 72,
#   '51': 69,
#   '52': 62,
#   '53': 76,
#   '54': 58,
#   '55': 60,
#   '56': 70,
#   '57': 73,
#   '58': 75,
#   '59': 81,
#   '60': 66,
#   '61': 71,
#   '62': 76,
#   '63': 90,
#   '64': 69,
#   '65': 81,
#   '66': 90,
#   '67': 80,
#   '68': 82,
#   '69': 78,
#   '70': 73,
#   '71': 78,
#   '72': 79,
#   '73': 72,
#   '74': 75,
#   '75': 83,
#   '76': 89,
#   '77': 86,
#   '78': 84,
#   '79': 94,
#   '80': 88,
#   '81': 70,
#   '82': 78,
#   '83': 64,
#   '84': 86,
#   '85': 74,
#   '86': 82,
#   '87': 61,
#   '88': 53,
# ...

# %%
def convert_to_df(stats: dict):
    data = {"dataset": [], "length": []}
    for dataset in stats:
        if "total" in dataset:
            continue
        dataset_name = dataset.split()[0]
        dist = stats[dataset]
        for key in dist:
            val = dist[key]
            for i in range(val):
                data["dataset"].append(dataset_name)
                data["length"].append(int(key))
    df = pd.DataFrame.from_dict(data)
    return df

# %%
df = convert_to_df(stats)
df
# Out:
#                dataset  length
# 0        aburaed_et_at      16
# 1        aburaed_et_at      20
# 2        aburaed_et_at      22
# 3        aburaed_et_at      23
# 4        aburaed_et_at      23
# ...                ...     ...
# 1061733  xing_et_al_hr    2298
# 1061734  xing_et_al_hr    3310
# 1061735  xing_et_al_hr    3519
# 1061736  xing_et_al_hr    4644
# 1061737  xing_et_al_hr    5239
#
# [1061738 rows x 2 columns]

# %%
sns.set(rc = {'figure.figsize':(15,8)})
sns.histplot(data=df, x="length", hue="dataset", binwidth=200, binrange=(0,20000))
# Out:
# <AxesSubplot:xlabel='length', ylabel='Count'>

# %%
longer_than_4096 = df.loc[df["length"] >= 4096]
percentage = 100*(len(longer_than_4096)/len(df))
print(f"{len(longer_than_4096)} out of {len(df)} are longer than 4096 e.g. {percentage}%")
# Out:
# 127483 out of 530869 are longer than 4096 e.g. 24.01402229175183%

# %%
fig, axes = plt.subplots(2, 2, figsize=(18, 10))
